# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import files

# %%
dataset = files.upload()
# Out:
#      <input type="file" id="files-0a98c10c-8b94-47fe-8e44-ccfe79f9d007" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0a98c10c-8b94-47fe-8e44-ccfe79f9d007">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("SLR2_Linear regression dataset 1.csv")

# %%
df.head(10)
# Out:
#    fertility rate  worker percent
# 0            3.71           28.33
# 1            3.59           28.72
# 2            3.48           29.18
# 3            3.37           29.67
# 4            3.27           30.17
# 5            3.17           30.66
# 6            3.07           31.02
# 7            2.97           31.40
# 8            2.88           31.77
# 9            2.78           32.13

# %%
X = df.iloc[:, :-1].values
Y = df.iloc[:, -1].values
print(X, Y)
# Out:
# [[3.71]
#  [3.59]
#  [3.48]
#  [3.37]
#  [3.27]
#  [3.17]
#  [3.07]
#  [2.97]
#  [2.88]
#  [2.78]
#  [2.69]
#  [2.6 ]
#  [2.52]
#  [2.45]
#  [2.38]
#  [2.32]
#  [2.27]
#  [2.23]
#  [2.19]
#  [2.15]
#  [2.12]
#  [2.09]
#  [2.06]] [28.33 28.72 29.18 29.67 30.17 30.66 31.02 31.4  31.77 32.13 32.5  32.74
#  33.5  34.29 35.1  35.94 36.77 37.62 38.49 39.38 40.29 41.21 44.04]

# %%
df.count()
# Out:
# fertility rate    23
# worker percent    23
# dtype: int64

# %%
df.head(23)
# Out:
#     fertility rate  worker percent
# 0             3.71           28.33
# 1             3.59           28.72
# 2             3.48           29.18
# 3             3.37           29.67
# 4             3.27           30.17
# 5             3.17           30.66
# 6             3.07           31.02
# 7             2.97           31.40
# 8             2.88           31.77
# 9             2.78           32.13
# 10            2.69           32.50
# 11            2.60           32.74
# 12            2.52           33.50
# 13            2.45           34.29
# 14            2.38           35.10
# 15            2.32           35.94
# 16            2.27           36.77
# 17            2.23           37.62
# 18            2.19           38.49
# 19            2.15           39.38
# 20            2.12           40.29
# 21            2.09           41.21
# 22            2.06           44.04

# %% [markdown]
# Splitting dataset into training set and test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# Visualisation of Training set results

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Visualisation of Test Set results

# %%
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# DATASET 2

# %%
dataset = files.upload()
# Out:
#      <input type="file" id="files-81283956-e153-4d50-8b9b-f92b6b620fca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-81283956-e153-4d50-8b9b-f92b6b620fca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Salary_dataset_Linear Regression dataset 2.csv", )

# %%
df.head(10)
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0
# 5           5              3.0  56643.0
# 6           6              3.1  60151.0
# 7           7              3.3  54446.0
# 8           8              3.3  64446.0
# 9           9              3.8  57190.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['YearsExperience'].plot(kind='hist', bins=20, title='YearsExperience')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
df.count()
# Out:
# Unnamed: 0         30
# YearsExperience    30
# Salary             30
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'YearsExperience', 'Salary'], dtype='object')

# %%
df = df[['YearsExperience', 'Salary']]

# %%
df.head(10)
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0
# 5              3.0  56643.0
# 6              3.1  60151.0
# 7              3.3  54446.0
# 8              3.3  64446.0
# 9              3.8  57190.0

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, :-1].values


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# <h1><strong>
# Linear Regression in Python - sklearn</strong></h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model

# %%
diabetes = datasets.load_diabetes()

# %%
diabetes.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])

# %%
diabetes.data
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
diabetes.DESCR
# Out:
# '.. _diabetes_dataset:\n\nDiabetes dataset\n----------------\n\nTen baseline variables, age, sex, body mass index, average blood\npressure, and six blood serum measurements were obtained for each of n =\n442 diabetes patients, as well as the response of interest, a\nquantitative measure of disease progression one year after baseline.\n\n**Data Set Characteristics:**\n\n  :Number of Instances: 442\n\n  :Number of Attributes: First 10 columns are numeric predictive values\n\n  :Target: Column 11 is a quantitative measure of disease progression one year after baseline\n\n  :Attribute Information:\n      - age     age in years\n      - sex\n      - bmi     body mass index\n      - bp      average blood pressure\n      - s1      tc, total serum cholesterol\n      - s2      ldl, low-density lipoproteins\n      - s3      hdl, high-density lipoproteins\n      - s4      tch, total cholesterol / HDL\n      - s5      ltg, possibly log of serum triglycerides level\n      - s6      glu, blood sug
# ...

# %%
diabetes_X = diabetes.data[:, np.newaxis, 2]

# %% [markdown]
# PLACEMENT v/s PACKAGE REGRESSION

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

# %%
dataset = files.upload()
# Out:
#      <input type="file" id="files-3e2881cb-13d9-47b6-a50a-edccc145f085" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3e2881cb-13d9-47b6-a50a-edccc145f085">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('cgpa,package.txt')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel('Percentage')
plt.title('CGPA v/s Percentage')
plt.show()

# %%
X = df.iloc[:, :1] #1st column
y = df.iloc[:, 1:] #2nd column

# %%
X
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y
# Out:
#      package
# 0       3.26
# 1       1.98
# 2       3.25
# 3       3.67
# 4       3.57
# ..       ...
# 195     2.46
# 196     2.57
# 197     3.24
# 198     3.96
# 199     2.33
#
# [200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2)

# %%
X_test
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57
# 85   4.79
# 10   5.32
# 54   6.86
# 115  8.35
# 35   6.87
# 12   8.94
# 92   7.90
# 13   6.93
# 126  5.91
# 174  7.32
# 2    7.82
# 44   5.09
# 3    7.42
# 113  6.94
# 14   7.73
# 23   6.19
# 25   7.28
# 6    6.73
# 134  7.20
# 165  8.21
# 173  6.75
# 45   7.87
# 65   7.60
# 48   8.63
# 122  5.12
# 178  8.15
# 64   7.36
# 9    8.31
# 57   6.60
# 78   6.59
# 71   7.47
# 128  7.93
# 176  6.29
# 131  6.37
# 53   6.47
# 137  7.14
# 163  8.93
# 111  5.42
# 123  5.10
# 109  7.77
# 141  6.76
# 41   6.89
# 130  6.68
# 140  7.91
# 5    7.89
# 159  8.71
# 100  7.95
# 11   6.61
# 187  6.26
# 24   6.53
# 89   6.42
# 66   5.11
# 8    6.09
# 172  6.93
# 175  7.04

# %%
from sklearn.linear_model import LinearRegression

# %%
# make an object
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Testing the test dataset

# %%
lr.predict(X_test)
# Out:
# array([[3.89015204],
#        [3.09544039],
#        [2.38964753],
#        [2.57859995],
#        [1.66162498],
#        [1.78388831],
#        [2.07843178],
#        [2.93427509],
#        [3.76233128],
#        [2.93983252],
#        [4.09021931],
#        [3.5122472 ],
#        [2.97317706],
#        [2.4063198 ],
#        [3.1899166 ],
#        [3.46778781],
#        [1.95061103],
#        [3.24549084],
#        [2.97873449],
#        [3.41777099],
#        [2.56192768],
#        [3.16768691],
#        [2.86202858],
#        [3.12322751],
#        [3.68452735],
#        [2.87314343],
#        [3.49557493],
#        [3.34552448],
#        [3.91793916],
#        [1.9672833 ],
#        [3.6511828 ],
#        [3.2121463 ],
#        [3.74010159],
#        [2.78978207],
#        [2.78422464],
#        [3.27327796],
#        [3.52891947],
#        [2.61750192],
#        [2.66196131],
#        [2.71753555],
#        [3.08988297],
#        [4.08466188],
#        [2.13400602],
# ...

# %%
plt.scatter(df['cgpa'], df['package'])
plt.plot(X_train, lr.predict(X_train), color='red')
plt.xlabel('CGPA')
plt.ylabel('Package')
# Out:
# Text(0, 0.5, 'Package')

# %%
# values of slope, and y-intercept of best-fit line
slope = lr.coef_
intercept = lr.intercept_

# %%
slope, intercept
# Out:
# (array([[0.55574241]]), array([-0.87811784]))

# %%
# line equation => y = mx + b
# let us take the first record
# cgpa = 8.58 (actual)

# %%
#so, predicted value
slope * 8.58 + intercept
# Out:
# array([[3.89015204]])

# %% [markdown]
# The formula way

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
# consider the dependent and independent variables
X = df['cgpa']
Y = df['package']

#calculate the mean
x_mean = X.mean()
y_mean = Y.mean()

# %%
# calculate the difference of each and every data point with the mean
X = df['cgpa'] - x_mean
Y = df['package'] - y_mean

# %%
# squaring them
X_squared = X * X
Y_squared = Y * Y

# %%
# multiplying x-x_mean and y-y_mean
numerator = (X * Y).sum()
denominator = (X_squared).sum()

# %%
slope_of_line = numerator / denominator

# %%
slope_of_line
# Out:
# 0.5695912947937536

# %%
intercept = 3.26 - 0.5695 * 6.89

# %%
# predicting the values
def predict(a):
  return (float)(a)*0.5695 + intercept

# %%
print(predict(input("Enter your CGPA: ")))
# Out:
# Enter your CGPA: 10.00
# 5.031145

# %%
error =

# %%
mean_error = (-Y + new_list).mean()
print(mean_error)
# Out:
# 3.17732

# %%
# new formula y = b0 + b1 * x + mean_error
intercept + 0.012 * (6.89) + mean_error
# Out:
# 6.43732

# %% [markdown]
# <h2>Practice</h2>

# %%
data = {
    'Air Velocity': [20, 60, 100, 140, 180, 220, 260, 300, 340, 380],
    'Evaporation Coefficent': [0.18, 0.37, 0.35, 0.78, 0.56, 0.75, 1.18, 1.36, 1.17, 1.65]
}

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    Air Velocity  Evaporation Coefficent
# 0            20                    0.18
# 1            60                    0.37
# 2           100                    0.35
# 3           140                    0.78
# 4           180                    0.56

# %%
X = df['Air Velocity'].values
y = df['Evaporation Coefficent'].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
X_train = X_train.reshape((-1, 1))
X_test = X_test.reshape((-1, 1))
y_train = y_train.reshape((-1, 1))
y_test = y_test.reshape((-1, 1))

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([[0.50910314],
#        [1.46426009],
#        [0.82748879]])

# %%
y_test
# Out:
# array([[0.35],
#        [1.17],
#        [0.56]])

# %%
plt.scatter(X, y)
plt.plot(X_train, lr.predict(X_train), c='red')
# plt.xlabel('')
plt.show()

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(y_test, y_pred)

# %%
score
# Out:
# 0.49443396584464805
